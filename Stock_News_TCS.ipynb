# %%
from GoogleNews import GoogleNews
from newspaper import Article
import pandas as pd

# %%
googlenews=GoogleNews(start='06/01/2021',end='06/01/2021')
googlenews.search('Cipla')
df_f=pd.DataFrame()
for i in range(1,31):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)
    df_f=pd.concat([df,df_f])
    print(i)
googlenews.clear()
# Out:
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 1
# 'NoneType' object is not iterable
# 2
# 'NoneType' object is not iterable
# 3
# 'NoneType' object is not iterable
# 4
# 'NoneType' object is not iterable
# 5
# 'NoneType' object is not iterable
# 6
# 'NoneType' object is not iterable
# 7
# 'NoneType' object is not iterable
# 8
# 'NoneType' object is not iterable
# 9
# 'NoneType' object is not iterable
# 10
# 'NoneType' object is not iterable
# 11
# 'NoneType' object is not iterable
# 12
# 'NoneType' object is not iterable
# 13
# 'NoneType' object is not iterable
# 14
# 'NoneType' object is not iterable
# 15
# 'NoneType' object is not iterable
# 16
# 'NoneType' object is not iterable
# 17
# 'NoneType' object is not iterable
# 18
# 'NoneType' object is not iterable
# 19
# 'NoneType' object is not iterable
# 20
# 'NoneType' object is not iterable
# 21
# 'NoneType' object is not iterable
# 22
# 'NoneType' object is not iterable
# 23
# ...

# %%
googlenews=GoogleNews(start='06/01/2021',end='07/01/2021')
googlenews.search('Cipla Limited')
df_f1=pd.DataFrame()
for i in range(1,31):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)
    df_f1=pd.concat([df,df_f1])
    print(i)
googlenews.clear()
# Out:
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 1
# 'NoneType' object is not iterable
# 2
# 'NoneType' object is not iterable
# 3
# 'NoneType' object is not iterable
# 4
# 'NoneType' object is not iterable
# 5
# 'NoneType' object is not iterable
# 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-8c52aac56607> in <module>
#       3 df_f1=pd.DataFrame()
#       4 for i in range(1,31):
# ----> 5     googlenews.getpage(i)
#       6     result=googlenews.result()
#       7     df=pd.DataFrame(result)
#
# ~/.local/lib/python3.8/site-packages/GoogleNews/__init__.py in getpage(self, page)
#     212     def getpage(self, page=1):
#     213         """Don't remove this, will affect old version user when upgrade"""
# --> 214         self.get_page(page)
#     215
#     216     def get_news(self, key="",deamplify=False):
#
# ...

# %%
df=pd.concat([df_f,df_f1],axis=0)
df=df.drop_duplicates().sort_values(by='datetime',ascending=True)
df_final=df.copy()
df_final
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-0f9951194697> in <module>
#       1 df=pd.concat([df_f,df_f1],axis=0)
# ----> 2 df=df.drop_duplicates().sort_values(by='datetime',ascending=True)
#       3 df_final=df.copy()
#       4 df_final
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5296
#    5297             by = by[0]
# -> 5298             k = self._get_label_or_level_values(by, axis=axis)
#    5299
#    5300             # need to rewrap column in Series to apply key function
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
# ...

# %%
df_final[df_final['date'].str.contains("Jan-2021")]

# %%
l=[]
df_final=df_final.fillna('')
for ind in range(df_final.shape[0]):
    d={}
    try:
        article = Article(df_final['link'].tolist()[ind])
        article.download()
        article.parse()
        article.nlp()
        d['Date']=df_final['date'].tolist()[ind]
        d['Media']=df_final['media'].tolist()[ind]
        d['Title']=article.title
        l.append(d)
        print("Done",ind)
        
    except:
        print(ind)
    #print(ind)
news_df=pd.DataFrame(l)
news_df.to_excel("/home/pogo/Desktop/Ba/Desktop/Books/Capstone/Phase 2/Parallel/Data/NEWS/TCS_articles_final.xlsx")
# Out:
# Done 0
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100
# ...
