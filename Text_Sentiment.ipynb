# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import functools
import operator
import re
import textblob
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk.data
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import sentiment

# %%
df=pd.read_excel("/home/pogo/Desktop/Ba/Desktop/Books/Capstone/Phase 2/Parallel/Data/NEWS/MakeMyTrip_Updated_articles_final_Jan.xlsx")
df=df.dropna()
df['Date']=list(df['Date'].apply(lambda x:x.strip()))
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Media', 'Title', 'Summary'], dtype='object')

# %%
df=df.astype(str)
df['Title_Refined']=list(df['Title'].apply(lambda x:str.lower(x)))
df['Title_Refined']
# Out:
# 0      consolidation and shakeouts: aviation to get r...
# 1      tax refund scheme benefits extended to all exp...
# 2      how your credit card is going to be more benef...
# 3      lpg cylinder booking: govt launches new missed...
# 4      how to make online appointment for aadhaar sev...
#                              ...
# 189                    sotc announces physical roadshows
# 190    pm modi to lead an all-party meeting to presen...
# 191    india's april-dec fiscal deficit reaches 145% ...
# 192    happy about jabs, worried about jobs: india's ...
# 193    shree cements reports two-fold jump in q3 prof...
# Name: Title_Refined, Length: 184, dtype: object

# %%
def define_sentiment(x):
#        sid_obj = SentimentIntensityAnalyzer()
#        sentiment_dict = sid_obj.polarity_scores(x)
#        return sentiment_dict['compound']
         senti=textblob.TextBlob(x)
         return senti.sentiment[0]

# %%
compound=[]
for i in df['Title_Refined'].tolist():
    compound.append(define_sentiment(i))

# %%
df['Sentiment Score']=compound
df
# Out:
#     Unnamed: 0         Date                Media  \
# 0            0  01-Jan-2021   The Economic Times
# 1            1  01-Jan-2021          Goodreturns
# 2            2  01-Jan-2021          Goodreturns
# 3            3  02-Jan-2021          Goodreturns
# 4            4  02-Jan-2021          Goodreturns
# ..         ...          ...                  ...
# 189        189  30-Jan-2021  Travel Trends Today
# 190        190  30-Jan-2021          Goodreturns
# 191        191  30-Jan-2021          Goodreturns
# 192        192  30-Jan-2021   The Economic Times
# 193        193  30-Jan-2021          Goodreturns
#
#                                                  Title  \
# 0    Consolidation and shakeouts: Aviation to get r...
# 1    Tax Refund Scheme Benefits Extended To All Exp...
# 2    How Your Credit Card Is Going To Be More Benef...
# 3    LPG Cylinder Booking: Govt Launches New Missed...
# 4    How To Make Online Appointment For Aadhaar Sev...
# ..                                                 ...
# 189                  SOTC announces physical roadshows
# 190  PM Modi To Lead An All-Party Meeting To Presen...
# 191  India's April-Dec Fiscal Deficit Reaches 145% ...
# 192  Happy about jabs, worried about jobs: India's ...
# 193  Shree Cements Reports Two-Fold Jump In Q3 Prof...
#
#                                                Summary  \
# 0    Consolidation and shakeouts: Aviation to get r...
# 1    Tax Refund Scheme Benefits Extended To All Exp...
# 2    How Your Credit Card Is Going To Be More Benef...
# 3    LPG Cylinder Booking: Govt Launches New Missed...
# 4    How To Make Online Appointment For Aadhaar Sev...
# ..                                                 ...
# 189  Indians are displaying a strong appetite for h...
# 190  PM Modi To Lead An All-Party Meeting To Presen...
# 191  India's April-Dec Fiscal Deficit Reaches 145% ...
# 192  In a highly informal economy, where unorganise...
# 193  Shree Cements Reports Two-Fold Jump In Q3 Prof...
#
#                                          Title_Refined  Sentiment Score
# 0    consolidation and shakeouts: aviation to get r...         0.000000
# 1    tax refund scheme benefits extended to all exp...         0.000000
# 2    how your credit card is going to be more benef...         0.500000
# 3    lpg cylinder booking: govt launches new missed...         0.136364
# 4    how to make online appointment for aadhaar sev...         0.000000
# ..                                                 ...              ...
# 189                  sotc announces physical roadshows         0.000000
# 190  pm modi to lead an all-party meeting to presen...         0.000000
# 191  india's april-dec fiscal deficit reaches 145% ...         0.350000
# 192  happy about jabs, worried about jobs: india's ...         0.800000
# 193  shree cements reports two-fold jump in q3 prof...         0.000000
#
# [184 rows x 7 columns]

# %%
#df[df['Sentiment Score']>0].groupby('Date').count()
def label_setup(x):
    if x==0:
        return 0
    elif x>0:
        return 1
    else:
        return -1

# %%
df['Class Label']=list(df['Sentiment Score'].apply(lambda x:label_setup(x)))
df
# Out:
#     Unnamed: 0         Date                Media  \
# 0            0  01-Jan-2021   The Economic Times
# 1            1  01-Jan-2021          Goodreturns
# 2            2  01-Jan-2021          Goodreturns
# 3            3  02-Jan-2021          Goodreturns
# 4            4  02-Jan-2021          Goodreturns
# ..         ...          ...                  ...
# 189        189  30-Jan-2021  Travel Trends Today
# 190        190  30-Jan-2021          Goodreturns
# 191        191  30-Jan-2021          Goodreturns
# 192        192  30-Jan-2021   The Economic Times
# 193        193  30-Jan-2021          Goodreturns
#
#                                                  Title  \
# 0    Consolidation and shakeouts: Aviation to get r...
# 1    Tax Refund Scheme Benefits Extended To All Exp...
# 2    How Your Credit Card Is Going To Be More Benef...
# 3    LPG Cylinder Booking: Govt Launches New Missed...
# 4    How To Make Online Appointment For Aadhaar Sev...
# ..                                                 ...
# 189                  SOTC announces physical roadshows
# 190  PM Modi To Lead An All-Party Meeting To Presen...
# 191  India's April-Dec Fiscal Deficit Reaches 145% ...
# 192  Happy about jabs, worried about jobs: India's ...
# 193  Shree Cements Reports Two-Fold Jump In Q3 Prof...
#
#                                                Summary  \
# 0    Consolidation and shakeouts: Aviation to get r...
# 1    Tax Refund Scheme Benefits Extended To All Exp...
# 2    How Your Credit Card Is Going To Be More Benef...
# 3    LPG Cylinder Booking: Govt Launches New Missed...
# 4    How To Make Online Appointment For Aadhaar Sev...
# ..                                                 ...
# 189  Indians are displaying a strong appetite for h...
# 190  PM Modi To Lead An All-Party Meeting To Presen...
# 191  India's April-Dec Fiscal Deficit Reaches 145% ...
# 192  In a highly informal economy, where unorganise...
# 193  Shree Cements Reports Two-Fold Jump In Q3 Prof...
#
#                                          Title_Refined  Sentiment Score  \
# 0    consolidation and shakeouts: aviation to get r...         0.000000
# 1    tax refund scheme benefits extended to all exp...         0.000000
# 2    how your credit card is going to be more benef...         0.500000
# 3    lpg cylinder booking: govt launches new missed...         0.136364
# 4    how to make online appointment for aadhaar sev...         0.000000
# ..                                                 ...              ...
# 189                  sotc announces physical roadshows         0.000000
# 190  pm modi to lead an all-party meeting to presen...         0.000000
# 191  india's april-dec fiscal deficit reaches 145% ...         0.350000
# 192  happy about jabs, worried about jobs: india's ...         0.800000
# 193  shree cements reports two-fold jump in q3 prof...         0.000000
#
#      Class Label
# 0              0
# 1              0
# 2              1
# 3              1
# 4              0
# ..           ...
# 189            0
# 190            0
# 191            1
# 192            1
# 193            0
#
# [184 rows x 8 columns]

# %%
df.to_excel("/home/pogo/Desktop/Ba/Desktop/Books/Capstone/Phase 2/Parallel/Data/CALCULATIONS/MMYT_Jan.xlsx",index=0)
